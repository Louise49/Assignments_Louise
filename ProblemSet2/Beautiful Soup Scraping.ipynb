# %%
<h1>this is my first Beautiful Soup scraping with Panda.</h1>

# %%
import requests
import csv
from bs4 import BeautifulSoup
url = "https://www.bbc.com/zhongwen/trad/chinese_news"
response = requests.get(url)
soup = BeautifulSoup(response.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html id="responsive-news" lang="zh-Hant">
# <head prefix="og: http://ogp.me/ns#">
# <meta content="width=device-width, initial-scale=1, user-scalable=1" name="viewport"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>兩岸三地 - BBC News 中文</title>
# <link as="style" href="https://static.bbc.co.uk/news/1.273.03229/stylesheets/services/zhongwen/compact.css" media="(max-width: 599px)" rel="preload"/>
# <link as="style" href="https://static.bbc.co.uk/news/1.273.03229/stylesheets/services/zhongwen/tablet.css" media="(min-width: 600px) and (max-width: 1007px)" rel="preload"/>
# <link as="style" href="https://static.bbc.co.uk/news/1.273.03229/stylesheets/services/zhongwen/wide.css" media="(min-width: 1008px)" rel="preload"/>
# <script> window.orb_fig_blocking = true; </script>
# <link as="script" href="//fig.bbc.co.uk/frameworks/fig/2/fig.js?callback=orb.orb_fig" rel="preload"/>
# ...

# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup 
from time import sleep
from random import randint 
from time import time

header = ['title','url','details','post date']
data = []

quote_page = requests.get('https://www.bbc.com/zhongwen/trad/chinese_news') 
soup = BeautifulSoup(quote_page.content,'html.parser')
data = []
for article in soup.find_all('div',class_='eagle-item__body'):
     title = article.a.h3.text.encode('utf-8').strip() 
     decoded_title = title.decode('utf-8')
     url = article.a.get('href')
     excerpt = article.p.text.encode('utf-8').strip()
     decoded_excerpt = excerpt.decode('utf-8')
     date = article.ul.li.text.encode('utf-8').strip()
     decoded_date = date.decode('utf-8')
     print(decoded_title)
     print(url)
     print(decoded_excerpt)
     print(decoded_date)
     data.append((decoded_title, url, decoded_excerpt, decoded_date))
    
df = pd.DataFrame(data, 
  columns = header
)
df.to_csv('BBC-CHN.csv', sep='\t', encoding='utf-8')
# Out:
# 毛澤東前秘書李銳去世 曾三次受難呼籲民主憲政
# /zhongwen/trad/chinese-news-45990784
# 他曾身居高位，說服毛澤東推遲三峽工程上馬；也與許多其他中共高官一樣，在數次政治鬥爭、高層博弈中身陷囹圄，起起落落。
# 2019年 2月 16日
# BBC博客：習近平「紅寶書」登上App排行榜首
# /zhongwen/trad/chinese-news-47250294
# 50多年前，印有毛主席語錄的「紅寶書」幾乎在中國人手一本。而現在，很多人開始使用一個紅色圖標的手機App。
# 2019年 2月 16日
# 涉香港書商桂敏海案，瑞典召回駐華大使
# /zhongwen/trad/chinese-news-47249716
# 瑞典駐華大使林戴安因涉嫌香港書商桂敏海案被瑞典政府召回。
# 2019年 2月 15日
# 加拿大「藏獨」女生當選學生會長與中國留學生的抗議風波
# /zhongwen/trad/chinese-news-47235493
# 農曆新年剛過，加拿大多倫多大學卻因為藏族女生奇美拉莫當選學生會長掀起激烈波瀾……
# 2019年 2月 15日
# 《流浪地球》引熱議，中國式科幻全方位解讀
# /zhongwen/trad/chinese-news-47236820
# 隨著票房一路攀升，圍繞電影技術展開的討論逐漸上升到意識形態上的爭論，社會撕裂的跡象彌漫在網絡和社交媒體平台。這部電影所呈現的「中國式科幻」引發了怎樣的討論？
# 2019年 2月 15日
# 台灣AI機器人「美玉姨」如何幫助網民查核事實
# /zhongwen/trad/chinese-news-47208116
# 台灣工程師研發了一個網路機器人「美玉姨」，向網路謠言下戰帖，她要挑戰的不僅是假新聞。
# 2019年 2月 14日
# 服務於中國神秘中產的跨國「紅娘」
# /zhongwen/trad/chinese-news-46700595
# 梅愛偲的跨國婚戀平台上，男會員多是能承擔數十萬費用的中國中產，而烏克蘭當地女會員只需要交100人民幣的會費。
# 2019年 2月 14日
# 讀懂文革的哈佛「中國通」麥克法夸爾
# /zhongwen/trad/chinese-news-47223298
# ...

# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup 
from time import sleep
from random import randint 
from time import time

# quote_page = requests.get('http://startupbeat.hkej.com/?tag=fintech&paged=1')
# soup = BeautifulSoup(quote_page.text,'html.parser')

header = ['page #','title','url','details','post date']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
    quote_page = requests.get('http://startupbeat.hkej.com/?tag=fintech&paged='+str(i)) 
    sleep(randint(8,15))
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(quote_page.content,'html.parser')

    for article in soup.find_all("div", attrs={"class":"archive-text"}): 
    # for article in soup.find_all('div',class_='archive-text'):
         page_no = str(i)
         title = article.a.text.encode('utf-8').strip()
         decoded_title = title.decode('utf-8')            
         url = article.a.get('href')
         details = article.p.text.encode('utf-8').strip()
         decoded_details = details.decode('utf-8')
         post_date = article.div.ul.li.text
         print(decoded_title)
         print(url)
         print(decoded_details)
         print(post_date)
         data.append((page_no, decoded_title, url, decoded_details, post_date))
    
df = pd.DataFrame(data, 
  columns = header
)
df.to_csv('startup_beat_data_1.csv', sep='\t', encoding='utf-8')
# Out:
# ***** Page 1 in action *****
# Bitcoin爆，STO代之 (老占)
# http://startupbeat.hkej.com/?p=68582
# 那麼與資產掛鈎的STO有什麼優勢？STO簡單來說就是代表證券型代幣發行，必須與資產掛鈎，例如石油、現金、股份、不動產等，比特幣傳道者認為只要夠多人把比特幣視為數碼黃金，它就仍有驚人的價值。
# Posted January 23, 2019
# 貿易通傳環聯事件後eKYC查詢增
# http://startupbeat.hkej.com/?p=68486
# 繼早前儲值支付工具（SVF）發牌後，虛擬銀行亦將於本季發牌。鄭俊聰提到，金融機構希望發展遙距開戶服務，必須先解決如何就透過拍攝及上載身份證明文件來認證身份，貿易通提供的身份證明文件認證，正可回應業界的需求。
# Posted January 21, 2019
# 加密紀錄解決互信問題 港企建區塊鏈貿融平台
# http://startupbeat.hkej.com/?p=68465
# 本港初創CryptoBLK（區塊科技）聯合創辦人兼行政總裁王世松，嘗試把區塊鏈引入企業應用領域，並成功爭取「最保守」的傳統金融機構支持，營建區塊鏈貿易金融平台Voltron。
# Posted January 21, 2019
# 儲值支付商加入申虛銀牌
# http://startupbeat.hkej.com/?p=68411
# 金管局季內會發出首批虛擬銀行牌照，安永亞太區金融科技高級經理恩馬克（Marc Entwistle）表示，安永與多家申請者有溝通，根據其了解，申請人之中有來自香港、內地和金融科技公司，部分更已有儲值支付工具牌照。
# Posted January 18, 2019
# 大新推遙距開戶 定存4厘吸客  最快10分鐘啟動 可跨行轉賬
# http://startupbeat.hkej.com/?p=68405
# 大新銀行（02356）繼去年推出遙距貸款及信用卡申請後，再添加遙距開立存款戶口服務，該行產品部總經理及主管鄧子健指出，客戶最快約10分鐘可完成開戶，並即時啟動戶口，轉入資金及馬上作出跨銀行轉賬。
# Posted January 18, 2019
# 港產初創助小企融資周轉 (FundPark 孫慧來)
# ...
